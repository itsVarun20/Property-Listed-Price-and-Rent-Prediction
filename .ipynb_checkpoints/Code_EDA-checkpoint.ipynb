# %% [markdown]
# # Property Listed Price and Rent Prediction

# %% [markdown]
# ## *Loading Dataset*

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('./data/data.csv')
data
# Out:
#       State         City             Street  Zipcode  Bedroom  Bathroom  \
# 0        AL     Saraland           Scott Dr  36571.0      4.0       2.0
# 1        AL  Robertsdale    Cowpen Creek Rd  36567.0      3.0       2.0
# 2        AL  Gulf Shores  Spinnaker Dr #201  36542.0      2.0       2.0
# 3        AL      Chelsea         Mallet Way  35043.0      3.0       3.0
# 4        AL   Huntsville     Turtlebrook Ct  35811.0      3.0       2.0
# ...     ...          ...                ...      ...      ...       ...
# 22676    WY        Burns          Road 210a  82053.0      2.0       1.0
# 22677    WY         Cody        Lincoln Ave  82414.0      2.0       3.0
# 22678    WY       Dubois           Mason Dr  82513.0      2.0       2.0
# 22679    WY     Cheyenne        Carolina Rd  82009.0      3.0       2.0
# 22680    WY   Evansville             6th St  82636.0      3.0       3.0
#
#          Area        PPSq  LotArea  MarketEstimate  RentEstimate   Latitude  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22681 entries, 0 to 22680
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   State           22681 non-null  object
#  1   City            22681 non-null  object
#  2   Street          22681 non-null  object
#  3   Zipcode         22681 non-null  float64
#  4   Bedroom         22667 non-null  float64
#  5   Bathroom        22647 non-null  float64
#  6   Area            22681 non-null  float64
#  7   PPSq            22681 non-null  float64
#  8   LotArea         21779 non-null  float64
#  9   MarketEstimate  15445 non-null  float64
#  10  RentEstimate    16705 non-null  float64
#  11  Latitude        22681 non-null  float64
#  12  Longitude       22681 non-null  float64
#  13  ListedPrice     22681 non-null  float64
# dtypes: float64(11), object(3)
# memory usage: 2.4+ MB

# %%
data.describe()
# Out:
#             Zipcode       Bedroom      Bathroom          Area          PPSq  \
# count  22681.000000  22667.000000  22647.000000  22681.000000  22681.000000
# mean   50023.455403      3.393435      2.423299   2128.138398    222.641994
# std    29570.312497      1.050506      1.157670   1577.512556    202.811788
# min     1002.000000      0.000000      0.000000    120.000000      1.925926
# 25%    25419.000000      3.000000      2.000000   1400.000000    132.729544
# 50%    50703.000000      3.000000      2.000000   1849.000000    184.122149
# 75%    74134.000000      4.000000      3.000000   2466.000000    257.118205
# max    99950.000000     21.000000     25.000000  99990.000000   6117.071334
#
#             LotArea  MarketEstimate   RentEstimate      Latitude  \
# count  21779.000000    1.544500e+04   16705.000000  22681.000000
# mean       2.354870    4.870383e+05    2624.699192     39.751686
# std       16.128371    1.155986e+06    4029.614920      5.694751
# ...

# %%
data.sort_values('Zipcode')
# Out:
#      State          City               Street  Zipcode  Bedroom  Bathroom  \
# 9571    MA       Amherst        Sunderland Rd   1002.0      4.0       3.0
# 9109    MA   Belchertown       Mill Valley Rd   1007.0      3.0       2.0
# 9237    MA   Belchertown              Gold St   1007.0      3.0       2.0
# 9117    MA       Chester             Maple St   1011.0      5.0       2.0
# 9225    MA      Chicopee          Fairmont St   1013.0      2.0       1.0
# ...    ...           ...                  ...      ...      ...       ...
# 765     AK     Ketchikan              Mayo Ln  99901.0      3.0       2.0
# 715     AK  Coffman Cove             NE Minke  99918.0      1.0       1.0
# 546     AK  Coffman Cove              Coho Dr  99918.0      3.0       3.0
# 781     AK      Wrangell  .2 Mile Zimovia Hwy  99929.0      3.0       2.0
# 739     AK     Ketchikan          -D2 Loop Rd  99950.0      3.0       2.0
#
#         Area        PPSq   LotArea  MarketEstimate  RentEstimate   Latitude  \
# ...

# %%
data.isna().sum()
# Out:
# State                0
# City                 0
# Street               0
# Zipcode              0
# Bedroom             14
# Bathroom            34
# Area                 0
# PPSq                 0
# LotArea            902
# MarketEstimate    7236
# RentEstimate      5976
# Latitude             0
# Longitude            0
# ListedPrice          0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.eq(0).sum()
# Out:
# State               0
# City                0
# Street              0
# Zipcode             0
# Bedroom            32
# Bathroom           76
# Area                0
# PPSq                0
# LotArea           220
# MarketEstimate      0
# RentEstimate        0
# Latitude            0
# Longitude           0
# ListedPrice         0
# dtype: int64

# %% [markdown]
# ## *Data Cleaning*

# %%
df = data.copy()

# %%
# Convert Zipcode to string
df['Zipcode'] = df['Zipcode'].astype(int).astype(str)
df['Zipcode'] = df['Zipcode'].apply(lambda x: x.zfill(5) if len(x) == 4 else x)

# %%
df.head()
# Out:
#   State         City             Street Zipcode  Bedroom  Bathroom    Area  \
# 0    AL     Saraland           Scott Dr   36571      4.0       2.0  1614.0
# 1    AL  Robertsdale    Cowpen Creek Rd   36567      3.0       2.0  1800.0
# 2    AL  Gulf Shores  Spinnaker Dr #201   36542      2.0       2.0  1250.0
# 3    AL      Chelsea         Mallet Way   35043      3.0       3.0  2224.0
# 4    AL   Huntsville     Turtlebrook Ct   35811      3.0       2.0  1225.0
#
#          PPSq  LotArea  MarketEstimate  RentEstimate   Latitude  Longitude  \
# 0  148.636927   0.3805        240600.0        1599.0  30.819534 -88.095960
# 1  144.388889   3.2000             NaN           NaN  30.590004 -87.580376
# 2  274.000000      NaN             NaN           NaN  30.284956 -87.747920
# 3  150.629496   0.2600        336200.0        1932.0  33.357986 -86.608700
# 4  204.081633      NaN        222700.0        1679.0  34.775517 -86.440700
#
#    ListedPrice
# 0     239900.0
# 1     259900.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22681 entries, 0 to 22680
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   State           22681 non-null  object
#  1   City            22681 non-null  object
#  2   Street          22681 non-null  object
#  3   Zipcode         22681 non-null  object
#  4   Bedroom         22667 non-null  float64
#  5   Bathroom        22647 non-null  float64
#  6   Area            22681 non-null  float64
#  7   PPSq            22681 non-null  float64
#  8   LotArea         21779 non-null  float64
#  9   MarketEstimate  15445 non-null  float64
#  10  RentEstimate    16705 non-null  float64
#  11  Latitude        22681 non-null  float64
#  12  Longitude       22681 non-null  float64
#  13  ListedPrice     22681 non-null  float64
# dtypes: float64(10), object(4)
# memory usage: 2.4+ MB

# %%
df[df['LotArea'].isna()]
# Out:
#       State             City                       Street Zipcode  Bedroom  \
# 2        AL      Gulf Shores            Spinnaker Dr #201   36542      2.0
# 4        AL       Huntsville               Turtlebrook Ct   35811      3.0
# 10       AL       Huntsville          Chancel Dr SE #5046   35802      2.0
# 43       AL       Tuscaloosa                   22nd Ave E   35405      3.0
# 83       AL        Northport                  Dunston Cir   35475      4.0
# ...     ...              ...                          ...     ...      ...
# 22181    WI         Fredonia      Pine Ridge COURT UNIT G   53021      2.0
# 22210    WI  Menomonee Falls  N8925 Water STREET UNIT 401   53051      2.0
# 22300    WY         Pinedale                    Sylvan Ln   82941      0.0
# 22366    WY             Cody                Winchester Dr   82414      3.0
# 22387    WY           Arvada                    Barton Rd   82831      4.0
#
# ...

# %%
df.sort_values('Zipcode')
# Out:
#      State          City               Street Zipcode  Bedroom  Bathroom  \
# 9571    MA       Amherst        Sunderland Rd   01002      4.0       3.0
# 9109    MA   Belchertown       Mill Valley Rd   01007      3.0       2.0
# 9237    MA   Belchertown              Gold St   01007      3.0       2.0
# 9117    MA       Chester             Maple St   01011      5.0       2.0
# 9225    MA      Chicopee          Fairmont St   01013      2.0       1.0
# ...    ...           ...                  ...     ...      ...       ...
# 765     AK     Ketchikan              Mayo Ln   99901      3.0       2.0
# 715     AK  Coffman Cove             NE Minke   99918      1.0       1.0
# 546     AK  Coffman Cove              Coho Dr   99918      3.0       3.0
# 781     AK      Wrangell  .2 Mile Zimovia Hwy   99929      3.0       2.0
# 739     AK     Ketchikan          -D2 Loop Rd   99950      3.0       2.0
#
#         Area        PPSq   LotArea  MarketEstimate  RentEstimate   Latitude  \
# ...

# %%
df = df.dropna(subset=['Bedroom', 'Bathroom', 'LotArea'])
df.isna().sum()
# Out:
# State                0
# City                 0
# Street               0
# Zipcode              0
# Bedroom              0
# Bathroom             0
# Area                 0
# PPSq                 0
# LotArea              0
# MarketEstimate    6850
# RentEstimate      5675
# Latitude             0
# Longitude            0
# ListedPrice          0
# dtype: int64

# %%
df.shape
# Out:
# (21745, 14)

# %%
corr_cols = df.select_dtypes(include=['float64'])

# Calculate the correlation matrix
correlation_matrix = corr_cols.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='viridis', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
correlation_score_ListedPrice = correlation_matrix['ListedPrice'].sort_values(ascending=False)
correlation_score_RentEstimate = correlation_matrix['RentEstimate'].sort_values(ascending=False)

print('Correlation score for ListedPrice')
print('-'*35)
print(correlation_score_ListedPrice)

print('\nCorrelation score for RentEstimate')
print('-'*35)
print(correlation_score_RentEstimate)
# Out:
# Correlation score for ListedPrice
# -----------------------------------
# ListedPrice       1.000000
# MarketEstimate    0.992830
# RentEstimate      0.735841
# PPSq              0.661692
# Area              0.596509
# Bathroom          0.468773
# LotArea           0.294893
# Bedroom           0.261158
# Latitude          0.020081
# Longitude        -0.039316
# Name: ListedPrice, dtype: float64
#
# Correlation score for RentEstimate
# -----------------------------------
# RentEstimate      1.000000
# MarketEstimate    0.904965
# ListedPrice       0.735841
# PPSq              0.538994
# Area              0.509808
# Bathroom          0.493044
# Bedroom           0.278391
# LotArea           0.144389
# Latitude          0.013031
# Longitude        -0.015653
# Name: RentEstimate, dtype: float64

# %%
# Imputating RentEstimate and MarketEstimate values
from sklearn.linear_model import LinearRegression

imp_df = df.dropna(subset=['RentEstimate', 'MarketEstimate']) 

model_est = LinearRegression()
model_rent = LinearRegression()

model_est.fit(imp_df['ListedPrice'].values.reshape(-1, 1),imp_df['MarketEstimate'].values)
model_rent.fit(imp_df['MarketEstimate'].values.reshape(-1, 1),imp_df['RentEstimate'].values)

est_missing_data = df[df['MarketEstimate'].isna()]
est_predicted_values = model_est.predict(est_missing_data['ListedPrice'].values.reshape(-1, 1))
df.loc[df['MarketEstimate'].isna(), 'MarketEstimate'] = est_predicted_values

rent_missing_data = df[df['RentEstimate'].isna()]
rent_predicted_values = model_rent.predict(rent_missing_data['MarketEstimate'].values.reshape(-1, 1))
df.loc[df['RentEstimate'].isna(), 'RentEstimate'] = rent_predicted_values

# %%
df.reset_index(inplace=True)
df.drop(columns=['index'], inplace=True)
df.isna().sum()
# Out:
# State             0
# City              0
# Street            0
# Zipcode           0
# Bedroom           0
# Bathroom          0
# Area              0
# PPSq              0
# LotArea           0
# MarketEstimate    0
# RentEstimate      0
# Latitude          0
# Longitude         0
# ListedPrice       0
# dtype: int64

# %%
data[data['RentEstimate'].isna()]
# Out:
#       State           City                        Street  Zipcode  Bedroom  \
# 1        AL    Robertsdale               Cowpen Creek Rd  36567.0      3.0
# 2        AL    Gulf Shores             Spinnaker Dr #201  36542.0      2.0
# 9        AL        Madison  Highpointb Plan Grayson Lndg  35756.0      4.0
# 10       AL     Huntsville           Chancel Dr SE #5046  35802.0      2.0
# 12       AL  Fort Mitchell                 Old Glory Way  36856.0      4.0
# ...     ...            ...                           ...      ...      ...
# 22648    WY           Cody                    Cowgill Rd  82414.0      4.0
# 22661    WY       Greybull                     5th Ave N  82426.0      3.0
# 22665    WY         Lander                  Hillcrest Dr  82520.0      5.0
# 22672    WY        Jackson            S Glenwood St #304  83001.0      3.0
# 22677    WY           Cody                   Lincoln Ave  82414.0      2.0
#
# ...

# %%
df
# Out:
#       State         City           Street Zipcode  Bedroom  Bathroom    Area  \
# 0        AL     Saraland         Scott Dr   36571      4.0       2.0  1614.0
# 1        AL  Robertsdale  Cowpen Creek Rd   36567      3.0       2.0  1800.0
# 2        AL      Chelsea       Mallet Way   35043      3.0       3.0  2224.0
# 3        AL   Montgomery      Brampton Ln   36117      3.0       2.0  1564.0
# 4        AL         Boaz    Greenwood Ave   35957      3.0       2.0  1717.0
# ...     ...          ...              ...     ...      ...       ...     ...
# 21740    WY        Burns        Road 210a   82053      2.0       1.0  1112.0
# 21741    WY         Cody      Lincoln Ave   82414      2.0       3.0  1232.0
# 21742    WY       Dubois         Mason Dr   82513      2.0       2.0  2016.0
# 21743    WY     Cheyenne      Carolina Rd   82009      3.0       2.0  2930.0
# 21744    WY   Evansville           6th St   82636      3.0       3.0  2300.0
#
# ...

# %%
output_file = ('./data/Cleaned_data.csv')
df.to_csv(output_file, index=False)

# %% [markdown]
# ## *Data Visualization*

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df = pd.read_csv('./data/Cleaned_data.csv')

# %%
numerical_variables = df.dtypes[df.dtypes == 'float64'].index
categorical_variables = df.dtypes[df.dtypes == 'object'].index

# %%
#Histogram - Distribution of numerical variables
plt.figure(figsize = (15, 20))

index = 1
for variable in (numerical_variables):
    plt.subplot(5, 2, index)
    sns.histplot(x = df[variable], kde=True)
    plt.title(variable)
    index += 1
    plt.xlabel('')

plt.suptitle('Distribution of Numerical Variables', size=20, weight='bold', y=0.92)
plt.show()

# %%
print(f'Number of States: {df.State.nunique()}')
print(f'States: {df.State.unique()}') # missing HI-Hawaii
# Out:
# Number of States: 49
# States: ['AL' 'AK' 'AZ' 'AR' 'OK' 'MO' 'CA' 'CO' 'CT' 'DE' 'FL' 'GA' 'ID' 'MT'
#  'IL' 'IN' 'IA' 'KS' 'KY' 'LA' 'ME' 'MD' 'MA' 'MI' 'MN' 'MS' 'NE' 'NV'
#  'NH' 'NJ' 'NM' 'NY' 'NC' 'ND' 'OH' 'OR' 'PA' 'RI' 'SC' 'SD' 'TN' 'TX'
#  'UT' 'VT' 'VA' 'WA' 'WV' 'WI' 'WY']

# %%
plt.figure(figsize=(15, 7))
df['State'].value_counts().plot.bar()
plt.title("State-wise Frequency Distribution")
plt.show()

# %%
df.City.nunique()
# Out:
# 5385

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='City', data=df, order=df['City'].value_counts().head(50).index)
plt.xticks(rotation = 90)
plt.title('City-wise Frequency Distribution (Top 50)')
plt.show()

# %%
df.Street.nunique()
# Out:
# 18514

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Street', data=df, order=df['Street'].value_counts().head(50).index)
plt.xticks(rotation = 90)
plt.title('Street-wise Frequency Distribution (Top 50)')
plt.show()

# %%
df.Zipcode.nunique()
# Out:
# 9046

# %%
#Barplot - Outlier detection
plt.figure(figsize = (22, 8))

index = 1
for  variable in (numerical_variables):
    plt.subplot(2, 5, index)
    sns.boxplot(x = df[variable])
    plt.title(variable)
    index += 1
    plt.xlabel('')

plt.suptitle('Boxplot for Numerical Variables', size=20, weight='bold', y=0.97)
plt.show()

# %%
df[df.Bedroom >= 5]
# Out:
#       State           City            Street  Zipcode  Bedroom  Bathroom  \
# 14       AL      Irvington         Moores Ln    36544      5.0       3.0
# 18       AL         Mobile         Driver St    36617      6.0       4.0
# 24       AL   Russellville      Gaines Ave N    35654      6.0       4.0
# 33       AL  Fort Mitchell        Ottawa Trl    36856      5.0       4.0
# 72       AL       Cherokee         Barton Rd    35616      5.0       1.0
# ...     ...            ...               ...      ...      ...       ...
# 21726    WY        Bedford           Deer Rd    83112      7.0       6.0
# 21728    WY    Green River       Colorado Dr    82935      5.0       3.0
# 21729    WY         Lander      Hillcrest Dr    82520      5.0       3.0
# 21730    WY        Rawlins        E Davis St    82301      5.0       3.0
# 21731    WY      Wheatland  Sybille Creek Rd    82201      6.0       5.0
#
#           Area        PPSq  LotArea  MarketEstimate  RentEstimate   Latitude  \
# ...

# %%
df[df.ListedPrice >= 10000000]
df[df.Street == 'S Westgate Ave']
# Out:
#      State         City          Street  Zipcode  Bedroom  Bathroom    Area  \
# 2150    CA  Los Angeles  S Westgate Ave    90049      4.0       5.0  5476.0
#
#              PPSq   LotArea  MarketEstimate  RentEstimate  Latitude  \
# 2150  2190.467495  0.272475      12200200.0       23993.0  34.06086
#
#        Longitude  ListedPrice
# 2150 -118.472046   11995000.0

# %%
df.ListedPrice.describe().round(2)
# Out:
# count       21745.00
# mean       534012.64
# std       1475591.80
# min          4888.00
# 25%        229900.00
# 50%        349000.00
# 75%        508570.00
# max      72000000.00
# Name: ListedPrice, dtype: float64

# %%
df.ListedPrice
# Out:
# 534012.6392274086

# %%
# Listed Price vs other features
features1 = ['Bedroom', 'Bathroom', 'Area', 'PPSq', 'MarketEstimate', 'RentEstimate']

fig, axes = plt.subplots(2, 3, figsize=(15, 10))
axes = axes.flatten()

for i, feature in enumerate(features1):
    sns.scatterplot(x=df[feature], y=df['ListedPrice'], ax=axes[i])
    axes[i].set_title(f'Listed Price vs {feature}')
    axes[i].set_xlabel(feature)
    axes[i].set_ylabel('Listed Price')

plt.tight_layout()
plt.show()

# %%
# Rent Estimate vs other features
features2 = ['Bedroom', 'Bathroom', 'Area', 'PPSq', 'MarketEstimate', 'ListedPrice']

fig, axes = plt.subplots(2, 3, figsize=(15, 10))
axes = axes.flatten()

for i, feature in enumerate(features2):
    sns.scatterplot(x=df[feature], y=df['RentEstimate'], ax=axes[i])
    axes[i].set_title(f'RentEstimate vs {feature}')
    axes[i].set_xlabel(feature)
    axes[i].set_ylabel('RentEstimate')

plt.tight_layout()
plt.show()

# %%
df[df.RentEstimate >= 100000]
# Out:
#       State         City              Street  Zipcode  Bedroom  Bathroom  \
# 2296     CA  Los Angeles           Chalon Rd    90049      7.0       9.0
# 8402     MD      Potomac            River Rd    20854      5.0      10.0
# 9172     MA       Boston           Beacon St     2108      5.0       8.0
# 12141    NV    Las Vegas       Witchcraft Ct    89135      9.0       9.0
# 17956    TN    Nashville       Chickering Rd    37215      5.0      10.0
# 21526    WY       Wilson  N Granite Creek Rd    83014      4.0       7.0
#
#           Area         PPSq    LotArea  MarketEstimate   RentEstimate  \
# 2296   14000.0  2063.428571   1.308200    2.857260e+07  114471.000000
# 8402   30000.0  1163.333333   9.650000    3.186525e+07  105673.288047
# 9172   10858.0  2855.037760   0.099862    2.732450e+07  113746.000000
# 12141   9827.0  2391.370713   1.160000    2.116950e+07  109582.000000
# 17956  19811.0  2019.080309  49.720000    3.687690e+07  176194.000000
# ...

# %%
# Area vs other features
features3 = ['Bedroom', 'Bathroom', 'PPSq']

fig, axes = plt.subplots(1, 3, figsize=(12, 4))
axes = axes.flatten()

for i, feature in enumerate(features3):
    sns.scatterplot(x=df[feature], y=df['Area'], ax=axes[i])
    axes[i].set_title(f'Area vs {feature}')
    axes[i].set_xlabel(feature)
    axes[i].set_ylabel('Area')

plt.tight_layout()
plt.show()

# %%
# Area vs other features
features4 = ['Bathroom', 'PPSq', 'LotArea']

fig, axes = plt.subplots(1, 3, figsize=(12, 4))
axes = axes.flatten()

for i, feature in enumerate(features4):
    sns.scatterplot(x=df[feature], y=df['Bedroom'], ax=axes[i])
    axes[i].set_title(f'Bedroom vs {feature}')
    axes[i].set_xlabel(feature)
    axes[i].set_ylabel('Bedroom')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## *Model Developement*

# %% [markdown]
# Machine Learning Algorithms
# * Linear Regression (Ridge and Lasso Regression)
# * Random Forest
# * Gradient Boosting
# * XGBoosting
# * KNN
# * SVR
# * CatBoost, LightGBM, AdaBoost
