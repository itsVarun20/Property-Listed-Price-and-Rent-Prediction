# %% [markdown]
# # Property Listed Price and Rent Prediction

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('./data/data.csv')
df
# Out:
#       State         City             Street  Zipcode   Latitude   Longitude  \
# 0        AL     Saraland           Scott Dr  36571.0  30.819534  -88.095960
# 1        AL    Southside       Big Oak Dr W  35907.0  33.881050  -86.012436
# 2        AL  Robertsdale    Cowpen Creek Rd  36567.0  30.590004  -87.580376
# 3        AL  Gulf Shores  Spinnaker Dr #201  36542.0  30.284956  -87.747920
# 4        AL      Chelsea         Mallet Way  35043.0  33.357986  -86.608700
# ...     ...          ...                ...      ...        ...         ...
# 24516    WY        Burns          Road 210a  82053.0  41.149517 -104.439620
# 24517    WY         Cody        Lincoln Ave  82414.0  44.524570 -109.033844
# 24518    WY       Dubois           Mason Dr  82513.0  43.521640 -109.594050
# 24519    WY     Cheyenne        Carolina Rd  82009.0  41.138450 -105.052790
# 24520    WY   Evansville             6th St  82636.0  42.865440 -106.277450
#
#        Bedroom  Bathroom    Area        PPSq     LotArea  ConvertedLot  \
# 0          4.0       2.0  1614.0  148.636927     0.38050       0.38050
# 1          3.0       2.0  1474.0    0.000678     0.67034       0.67034
# 2          3.0       2.0  1800.0  144.388889     3.20000       3.20000
# 3          2.0       2.0  1250.0  274.000000         NaN           NaN
# 4          3.0       3.0  2224.0  150.629496     0.26000       0.26000
# ...        ...       ...     ...         ...         ...           ...
# 24516      2.0       1.0  1112.0  337.230216    20.00000      20.00000
# 24517      2.0       3.0  1232.0  241.801948  1306.80000       0.03000
# 24518      2.0       2.0  2016.0  262.896825     1.42000       1.42000
# 24519      3.0       2.0  2930.0  196.552901     6.23000       6.23000
# 24520      3.0       3.0  2300.0  143.434783  7575.08400       0.17390
#
#       LotUnit  MarketEstimate  RentEstimate     Price
# 0       acres        240600.0        1599.0  239900.0
# 1       acres        186700.0        1381.0       1.0
# 2       acres             NaN           NaN  259900.0
# 3         NaN             NaN           NaN  342500.0
# 4       acres        336200.0        1932.0  335000.0
# ...       ...             ...           ...       ...
# 24516   acres        368600.0        1500.0  375000.0
# 24517    sqft             NaN           NaN  297900.0
# 24518   acres             NaN        2294.0  530000.0
# 24519   acres        558000.0        2749.0  575900.0
# 24520    sqft        329500.0        1614.0  329900.0
#
# [24521 rows x 16 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24521 entries, 0 to 24520
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   State           24135 non-null  object
#  1   City            24135 non-null  object
#  2   Street          24104 non-null  object
#  3   Zipcode         24135 non-null  float64
#  4   Latitude        24135 non-null  float64
#  5   Longitude       24135 non-null  float64
#  6   Bedroom         23456 non-null  float64
#  7   Bathroom        23524 non-null  float64
#  8   Area            23029 non-null  float64
#  9   PPSq            22784 non-null  float64
#  10  LotArea         23103 non-null  float64
#  11  ConvertedLot    23103 non-null  float64
#  12  LotUnit         23103 non-null  object
#  13  MarketEstimate  15927 non-null  float64
#  14  RentEstimate    17649 non-null  float64
#  15  Price           24130 non-null  float64
# dtypes: float64(12), object(4)
# memory usage: 3.0+ MB

# %%
df.describe()
# Out:
#             Zipcode      Latitude     Longitude       Bedroom      Bathroom  \
# count  24135.000000  24135.000000  24135.000000  23456.000000  23524.000000
# mean   49803.793371     39.777742    -92.256964      3.388344      2.408036
# std    29582.441312      5.643364     16.815573      1.116027      1.193186
# min     1002.000000     25.449816   -161.772780      0.000000      0.000000
# 25%    25411.000000     35.984594   -103.394547      3.000000      2.000000
# 50%    50322.000000     39.966393    -89.139660      3.000000      2.000000
# 75%    74066.000000     42.954664    -79.148755      4.000000      3.000000
# max    99950.000000     65.044370    -67.016030     36.000000     30.000000
#
#                Area           PPSq       LotArea  ConvertedLot  \
# count  23029.000000   22784.000000  23103.000000  23103.000000
# mean    2110.278866     265.271433   2761.895076     11.157897
# std     1604.456529    4091.052158   3740.451139    598.769340
# min        0.000000       0.000000      0.000000      0.000000
# 25%     1386.000000     132.359951      0.529991      0.179100
# 50%     1840.000000     183.968122      4.500000      0.310000
# 75%     2458.000000     257.120253   6414.210000      1.000000
# max    99990.000000  550000.000000  87517.000000  87517.000000
#
#        MarketEstimate   RentEstimate         Price
# count    1.592700e+04   17649.000000  2.413000e+04
# mean     4.841942e+05    2595.383251  5.304693e+05
# std      1.139923e+06    3943.018444  1.687055e+06
# min      1.570000e+04     100.000000  0.000000e+00
# 25%      2.300500e+05    1599.000000  2.150000e+05
# 50%      3.411000e+05    2106.000000  3.350000e+05
# 75%      4.990000e+05    2800.000000  4.990000e+05
# max      7.195920e+07  212834.000000  7.600000e+07

# %%
df.sort_values('Zipcode')
# Out:
#       State         City          Street  Zipcode   Latitude  Longitude  \
# 9999     MA      Amherst   Sunderland Rd   1002.0  42.422096 -72.538150
# 9527     MA  Belchertown  Mill Valley Rd   1007.0  42.263100 -72.374750
# 9657     MA  Belchertown         Gold St   1007.0  42.342020 -72.410630
# 9535     MA      Chester        Maple St   1011.0  42.278910 -72.979530
# 9645     MA     Chicopee     Fairmont St   1013.0  42.185658 -72.598274
# ...     ...          ...             ...      ...        ...        ...
# 24284   NaN          NaN             NaN      NaN        NaN        NaN
# 24312   NaN          NaN             NaN      NaN        NaN        NaN
# 24321   NaN          NaN             NaN      NaN        NaN        NaN
# 24335   NaN          NaN             NaN      NaN        NaN        NaN
# 24362   NaN          NaN             NaN      NaN        NaN        NaN
#
#        Bedroom  Bathroom    Area        PPSq   LotArea  ConvertedLot LotUnit  \
# 9999       4.0       3.0  3120.0  181.089744  2.700000      2.700000   acres
# 9527       3.0       2.0  1512.0  210.978836  1.760000      1.760000   acres
# 9657       3.0       2.0  1296.0  270.061728  1.730000      1.730000   acres
# 9535       5.0       2.0  2136.0   46.816479  0.450000      0.450000   acres
# 9645       2.0       1.0  1008.0  237.996032  0.511387      0.511387   acres
# ...        ...       ...     ...         ...       ...           ...     ...
# 24284      NaN       NaN     NaN         NaN       NaN           NaN     NaN
# 24312      NaN       NaN     NaN         NaN       NaN           NaN     NaN
# 24321      NaN       NaN     NaN         NaN       NaN           NaN     NaN
# 24335      NaN       NaN     NaN         NaN       NaN           NaN     NaN
# 24362      NaN       NaN     NaN         NaN       NaN           NaN     NaN
#
#        MarketEstimate  RentEstimate     Price
# 9999         526800.0        3499.0  565000.0
# 9527         324600.0        2274.0  319000.0
# 9657         355000.0        2949.0  350000.0
# 9535          88900.0        2800.0  100000.0
# 9645         242000.0        1800.0  239900.0
# ...               ...           ...       ...
# 24284             NaN           NaN       NaN
# 24312             NaN           NaN       NaN
# 24321             NaN           NaN       NaN
# 24335             NaN           NaN       NaN
# 24362             NaN           NaN       NaN
#
# [24521 rows x 16 columns]

# %%
df.isna().sum()
# Out:
# State              386
# City               386
# Street             417
# Zipcode            386
# Latitude           386
# Longitude          386
# Bedroom           1065
# Bathroom           997
# Area              1492
# PPSq              1737
# LotArea           1418
# ConvertedLot      1418
# LotUnit           1418
# MarketEstimate    8594
# RentEstimate      6872
# Price              391
# dtype: int64

# %%
data = df.copy()

# %%
# Convert Zipcode to string
data['Zipcode'] = data['Zipcode'].astype(str)

# Standardize text data (example: City names)
data['City'] = data['City'].str.title()

# %%
data
# Out:
#       State         City             Street  Zipcode   Latitude   Longitude  \
# 0        AL     Saraland           Scott Dr  36571.0  30.819534  -88.095960
# 1        AL    Southside       Big Oak Dr W  35907.0  33.881050  -86.012436
# 2        AL  Robertsdale    Cowpen Creek Rd  36567.0  30.590004  -87.580376
# 3        AL  Gulf Shores  Spinnaker Dr #201  36542.0  30.284956  -87.747920
# 4        AL      Chelsea         Mallet Way  35043.0  33.357986  -86.608700
# ...     ...          ...                ...      ...        ...         ...
# 24516    WY        Burns          Road 210a  82053.0  41.149517 -104.439620
# 24517    WY         Cody        Lincoln Ave  82414.0  44.524570 -109.033844
# 24518    WY       Dubois           Mason Dr  82513.0  43.521640 -109.594050
# 24519    WY     Cheyenne        Carolina Rd  82009.0  41.138450 -105.052790
# 24520    WY   Evansville             6th St  82636.0  42.865440 -106.277450
#
#        Bedroom  Bathroom    Area        PPSq     LotArea  ConvertedLot  \
# 0          4.0       2.0  1614.0  148.636927     0.38050       0.38050
# 1          3.0       2.0  1474.0    0.000678     0.67034       0.67034
# 2          3.0       2.0  1800.0  144.388889     3.20000       3.20000
# 3          2.0       2.0  1250.0  274.000000         NaN           NaN
# 4          3.0       3.0  2224.0  150.629496     0.26000       0.26000
# ...        ...       ...     ...         ...         ...           ...
# 24516      2.0       1.0  1112.0  337.230216    20.00000      20.00000
# 24517      2.0       3.0  1232.0  241.801948  1306.80000       0.03000
# 24518      2.0       2.0  2016.0  262.896825     1.42000       1.42000
# 24519      3.0       2.0  2930.0  196.552901     6.23000       6.23000
# 24520      3.0       3.0  2300.0  143.434783  7575.08400       0.17390
#
#       LotUnit  MarketEstimate  RentEstimate     Price
# 0       acres        240600.0        1599.0  239900.0
# 1       acres        186700.0        1381.0       1.0
# 2       acres             NaN           NaN  259900.0
# 3         NaN             NaN           NaN  342500.0
# 4       acres        336200.0        1932.0  335000.0
# ...       ...             ...           ...       ...
# 24516   acres        368600.0        1500.0  375000.0
# 24517    sqft             NaN           NaN  297900.0
# 24518   acres             NaN        2294.0  530000.0
# 24519   acres        558000.0        2749.0  575900.0
# 24520    sqft        329500.0        1614.0  329900.0
#
# [24521 rows x 16 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24521 entries, 0 to 24520
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   State           24135 non-null  object
#  1   City            24135 non-null  object
#  2   Street          24104 non-null  object
#  3   Zipcode         24521 non-null  object
#  4   Latitude        24135 non-null  float64
#  5   Longitude       24135 non-null  float64
#  6   Bedroom         23456 non-null  float64
#  7   Bathroom        23524 non-null  float64
#  8   Area            23029 non-null  float64
#  9   PPSq            22784 non-null  float64
#  10  LotArea         23103 non-null  float64
#  11  ConvertedLot    23103 non-null  float64
#  12  LotUnit         23103 non-null  object
#  13  MarketEstimate  15927 non-null  float64
#  14  RentEstimate    17649 non-null  float64
#  15  Price           24130 non-null  float64
# dtypes: float64(11), object(5)
# memory usage: 3.0+ MB

# %%
data.describe()
# Out:
#            Latitude     Longitude       Bedroom      Bathroom          Area  \
# count  24135.000000  24135.000000  23456.000000  23524.000000  23029.000000
# mean      39.777742    -92.256964      3.388344      2.408036   2110.278866
# std        5.643364     16.815573      1.116027      1.193186   1604.456529
# min       25.449816   -161.772780      0.000000      0.000000      0.000000
# 25%       35.984594   -103.394547      3.000000      2.000000   1386.000000
# 50%       39.966393    -89.139660      3.000000      2.000000   1840.000000
# 75%       42.954664    -79.148755      4.000000      3.000000   2458.000000
# max       65.044370    -67.016030     36.000000     30.000000  99990.000000
#
#                 PPSq       LotArea  ConvertedLot  MarketEstimate  \
# count   22784.000000  23103.000000  23103.000000    1.592700e+04
# mean      265.271433   2761.895076     11.157897    4.841942e+05
# std      4091.052158   3740.451139    598.769340    1.139923e+06
# min         0.000000      0.000000      0.000000    1.570000e+04
# 25%       132.359951      0.529991      0.179100    2.300500e+05
# 50%       183.968122      4.500000      0.310000    3.411000e+05
# 75%       257.120253   6414.210000      1.000000    4.990000e+05
# max    550000.000000  87517.000000  87517.000000    7.195920e+07
#
#         RentEstimate         Price
# count   17649.000000  2.413000e+04
# mean     2595.383251  5.304693e+05
# std      3943.018444  1.687055e+06
# min       100.000000  0.000000e+00
# 25%      1599.000000  2.150000e+05
# 50%      2106.000000  3.350000e+05
# 75%      2800.000000  4.990000e+05
# max    212834.000000  7.600000e+07
